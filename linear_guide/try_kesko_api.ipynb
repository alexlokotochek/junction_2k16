# %%
import httplib
import json

def have_numeric(str):
    for c in str:
        if (c.isnumeric()):
            return True
    return False

def split_with_first_numeric(av):
    if '100%' == av[:4]:
        av = av[4:]
    if (av[0].isnumeric() or av[1].isnumeric()):
        for i in range(len(av) - 1, -1, -1):
            if av[i].isnumeric():
                return [av[i + 1:], av[:i + 1]]
    print av
    for i, c in enumerate(av):
        if c.isnumeric():
            return [av[:i], av[i:]]

# %%
conn = httplib.HTTPSConnection("api.eu.apiconnect.ibmcloud.com")
headers = {
    'x-ibm-client-id': "7ddb67df-4c7b-4fa3-ab1f-1a5c3cd2dfc8",
    'x-ibm-client-secret': "pF0lJ3cV0vO4tJ7yF5gE5aX5oK6mI7nM8eR5cM0yI2cY8fD5lQ",
    'content-type': "application/json",
    'accept': "application/json",
    'accept-language': "fi"
    }


total = 300000
step = int(total/300)
#"""
products = []
for offset in range(0, total+1, 100):
    if offset % step == 0:
        print(int(offset/step), '/ 10...')
    payload = "{\"view\":{\"limit\":100,\"offset\":"+str(offset)+"}}"
    conn.request("POST", "/kesko-dev-rauta-api/qa/products/actions/search", payload, headers)
    res = conn.getresponse()
    data = res.read()
    if len(data) < 1000:
        break
    data = json.loads(data.decode("utf-8")) 
    if 'results' not in data:
        break
    data = data['results']
    for product in data:
        products.append(product)       
#"""
# Out:
# (0, '/ 10...')
# (1, '/ 10...')
# (2, '/ 10...')
# (3, '/ 10...')
# (4, '/ 10...')
# (5, '/ 10...')
# (6, '/ 10...')
# (7, '/ 10...')
# (8, '/ 10...')
# (9, '/ 10...')
# (10, '/ 10...')

# %%
productid_to_attrs = {}
productid_to_cat = {}
productid_to_img = {}
cat_to_productids = {}

# %%
fuck_up = 0
total = 0
for product in products:
    if 'attributes' in product and 'articleFeatures' in product['attributes']:
        if (len(product['attributes']['articleFeatures'].split('System.Collections')) > 1):
            #print "Fuck"
            continue
        atrs = product['attributes']['articleFeatures'].split('\n')
        for i in range(0, len(atrs)):
            if (atrs[i][0:1] == '- '):
                atrs[i] = atrs[i][2:]
        if not atrs or len(atrs)==0:
            continue
        #atrs = list(map(lambda atr:split_with_first_numeric(atr), atrs))
        total += len(atrs)
        for i in range(0, len(atrs)):
            while atrs[i] and len(atrs[i]) > 0 and (atrs[i][0] == ' ' or atrs[i][0] == ',' or atrs[i][0] == '-'):
                atrs[i] = atrs[i][1:]
            while atrs[i] and len(atrs[i]) > 0 and (atrs[i][-1] == ' ' or atrs[i][-1] == ',' or atrs[i][-1] == '-'):
                atrs[i] = atrs[i][:-1]
            if (len(atrs[i].split(" ")) == 2 and len(atrs[i].split(" ")[0]) > 0 and len(atrs[i].split(" ")[1]) > 0):
                atrs[i] = atrs[i].split(" ")
            elif (len(atrs[i].split(":")) == 2 and len(atrs[i].split(":")[0]) > 0 and len(atrs[i].split(":")[1]) > 0):
                atrs[i] = atrs[i].split(":")
            elif (have_numeric(atrs[i])):
                atrs[i] = split_with_first_numeric(atrs[i])
            else:
                fuck_up += 1
                atrs[i] = None
                continue
            if (atrs[i]):
                for j in range(0, 2):
                    while atrs[i][j] and len(atrs[i][j]) > 0 and (atrs[i][j][0] == ' ' or atrs[i][j][0] == ',' or atrs[i][j][0] == '-'):
                        atrs[i][j] = atrs[i][j][1:]
                    while atrs[i][j] and len(atrs[i][j]) > 0 and (atrs[i][j][-1] == ' ' or atrs[i][j][-1] == ',' or atrs[i][j][-1] == '-'):
                        atrs[i][j] = atrs[i][j][:-1]
                if (len(atrs[i][0]) > 0 and len(atrs[i][1]) > 0):
                    atrs[i] = (atrs[i][0], atrs[i][1])
                elif len(atrs[i][0]) > 0:
                    atrs[i] = (atrs[i][0], atrs[i][0])
                else:
                    atrs[i] = (atrs[i][1], atrs[i][1])
            
        atrs_ = []
        for a in atrs:
            if a:
                atrs_.append(a)
        atrs = atrs_
        this_id = product['id']
        this_cat = product['categoryId']
        productid_to_cat[this_id] = this_cat
        if this_cat not in cat_to_productids:
            cat_to_productids[this_cat] = []
        cat_to_productids[this_cat] += [this_id]
        if 'images' in product:
            productid_to_img[this_id] = product['images'][0]['url']
        #if this_id in productid_to_attrs:
            #print('collision!', this_id)
        productid_to_attrs[this_id] = {}
        for atr, value in atrs:
            productid_to_attrs[this_id][atr] = value
print fuck_up, total
# Out:
# Ottoteho 440 W
# Iskuluku 0-5000 min-1
# Paino 1,9 kg
#  puuvilla, twill, 370g/m²
#  puuvilla, twill, 370g/m²
#  puuvilla, twill, 370g/m²
#  puuvillajersey, 180 g/m²
#  puuvilla twill, 320 g/m²
#  puuvilla, twill, 370g/m²
# Pituus 50 mm
# vedenimukykyluokka BIII (>10%)
# ottoteho 750 W
# nauhan koko 75 x 533 mm
# nauhan nopeus 200–330 m/min.
# Korkeus 0,2 m.
# Leveys 2 m.
# teho 80 W
# terän oskillaatioliike 2,8 mm
# kierroslukualue 15000-21000 min-1
# kovettuu n. 15 minuutissa
# ottoteho 1100 W
# kierrosluku 8000-24000 min-1
# syöttöliike 0-57 mm
# värivaihtelu V2 (melko vähän)
# vedenimukykyluokka BIII (>10%)
# terän oskillaatioliike 2,8 mm
# kierroslukualue 15000-21000 min-1
# Pituus 20 m
# teho 1800 W
# kapasiteetti 75,5 mm
# kovapalaterä 210x30 mm 48 h
# Pituus 90 mm
# Korkeus noin 15 - 25 cm.
# yhdyskaapeli 3 m (optiona 5/10 m)
# saunan koko 7-12 m³
# kivimäärä maks. 20 kg
# Lujuus HRC 58
# Kärki kolmiohiottu 4 mm.
# Korkeus noin 10 cm.
# kasvukorkeus n. 1-3 m
# ...

# %%
productid_to_attrs_ = {}
for id_, atrs in productid_to_attrs.items():
#     print(id, ':', atrs)
    if len(atrs) != 0:
        productid_to_attrs_[id_] = atrs
productid_to_attrs = productid_to_attrs_

# %%
len(productid_to_attrs),len(productid_to_cat),len(productid_to_img),len(cat_to_productids)
# Out:
# (879, 1005, 1005, 253)

# %%
for id, atrs in list(productid_to_attrs.items())[:10]:
    print(id, ':', atrs)
# Out:
# (500209664, ':', {u'kierrosluku': u'4800 min-1', u'ter\xe4': u'260x30, 48 hammasta', u'ottoteho': u'1650 W', u'kapasiteetti p\xf6yt\xe4': u'90\xb0  93 mm'})
# (500230145, ':', {u'iskunvaimennuspohjallinen': u'C2', u'Pit\xe4v\xe4': u'grip-kumipohja'})
# (500211371, ':', {u'kpl kalvotiivisteit\xe4': u'12'})
# (500342792, ':', {u'sementtipohjainen': u'jauhe', u'saumaleveyksille': u'2-6 mm', u'suihkutiivis EN': u'13888 CG2 WA', u'pitk\xe4': u'avoaika'})
# (500209676, ':', {u'Naulat': u'18G 20-50 mm'})
# (500230158, ':', {u'iskunvaimennuspohjallinen': u'C2', u'Pit\xe4v\xe4': u'grip-kumipohja'})
# (500068367, ':', {u'saatavissa': u'\xe4\xe4nieristysovia', u'vuoden tuotetakuu': u'2'})
# (500068369, ':', {u'vuoden tuotetakuu': u'2', u'tehty': u'Suomessa'})
# (500068370, ':', {u'vuoden tuotetakuu': u'2', u'tehty': u'Suomessa'})
# (500068371, ':', {u'vuoden tuotetakuu': u'2', u'tehty': u'Suomessa'})

# %%
atr_count = {}
atr_val_count = {}
for id, atrs in list(productid_to_attrs.items()):
    for atr, val in atrs.items():
        if atr not in atr_count:
            atr_count[atr] = 0
        atr_count[atr] += 1
        if (atr, val) not in atr_val_count:
            atr_val_count[(atr, val)] = 0
        atr_val_count[(atr, val)] += 1

# %%
for atr, count in sorted(atr_count.items(), key=lambda tup:tup[1], reverse=True)[:10]:
    print(atr, '_:_', count)
# Out:
# (u'Pituus', '_:_', 44)
# (u'Korkeus noin', '_:_', 40)
# (u'puuvilla, twill', '_:_', 38)
# (u'Paino', '_:_', 37)
# (u'ottoteho', '_:_', 35)
# (u'kasvukorkeus n.', '_:_', 26)
# (u'Materiaalit', '_:_', 24)
# (u'teho', '_:_', 23)
# (u'Tuotteen mitat', '_:_', 23)
# (u'paino', '_:_', 21)

# %%
for atrval, count in sorted(atr_val_count.items(), key=lambda tup:tup[1], reverse=True)[:10]:
    print(atrval[0],'=',atrval[1], '_:_', count)
# Out:
# (u'puuvilla, twill', '=', u'370g/m\xb2', '_:_', 38)
# (u'vuoden takuu', '=', u'10', '_:_', 17)
# (u'2-komponentti', '=', u'kahvalla', '_:_', 16)
# (u'100%', '=', u'polyesteri', '_:_', 15)
# (u'3', '=', u'sauvainen', '_:_', 13)
# (u'100 % puuvillatwill, 370 g/m\xb2', '=', u'100 % puuvillatwill, 370 g/m\xb2', '_:_', 13)
# (u'vuoden tuotetakuu', '=', u'2', '_:_', 13)
# (u'35% puuvilla twill, 240 g/m\xb2', '=', u'35% puuvilla twill, 240 g/m\xb2', '_:_', 11)
# (u'65%', '=', u'polyesteri', '_:_', 11)
# (u'polyesteri', '=', u'185g/m\xb2', '_:_', 10)

# %%
# productid_to_attrs = {}
# productid_to_cat = {}
# productid_to_img = {}
# cat_to_productids = {}

# %%
cat_to_productids = {}
for product, cat in productid_to_cat.items():
    if cat not in cat_to_productids:
        cat_to_productids[cat] = set([])
    cat_to_productids[cat] |= set([product])

# %%
cat_to_productids_ = {}
for cat, prods_list in cat_to_productids.items():
    if len(prods_list) >= 1:
        cat_to_productids_[cat] = prods_list
    
cat_to_productids = cat_to_productids_

# %%
len(cat_to_productids)
# Out:
# 253

# %%
sorted(cat_to_productids.items(), key=lambda tup:len(tup[1]), reverse=True)[1][0]
# Out:
# 42215040

# %%
categories = {}
for gc in cat_to_productids.keys():
    cat = gc
#     print gc[0], gc[1], len(cat_to_productids[gc[0]])
    this_prods = list(cat_to_productids[cat])
    atrs_for_all = set([])
    for prod in this_prods:
#         print prod, productid_to_attrs[prod]
        if prod in productid_to_attrs:
            atrs_for_all |= set(productid_to_attrs[prod].keys())
#     for at in atrs_for_all:
#         print at
#     print
    atrs_diff_count = {}
    products_have_atr = {}
    counted_atrs = 0
    questions = {}
    for atr in atrs_for_all:
#         if atr == 'name_of_product':
#             continue
        products_have_atr[atr] = 0
        atrs_diff_count[atr] = set([])
        for prod in this_prods:
            if prod in productid_to_attrs and atr in productid_to_attrs[prod]:
                products_have_atr[atr] += 1
                val = productid_to_attrs[prod][atr]
                if type(val) != int and type(val) != float and len(val) > 0:
                    atrs_diff_count[atr] |= set([val])
        if len(atrs_diff_count[atr]) > 1:# and len(atrs_diff_count[atr]) < products_have_atr[atr]*0.1 and products_have_atr[atr] > 0.5 * len(this_prods):
#             print atr
            questions['Q_'+str(counted_atrs)] = {}
            questions['Q_'+str(counted_atrs)]['text'] = atr
            counted_vals = 0
            for val in list(atrs_diff_count[atr]):
#                 if ',' in val or '/' in val or type(val) == int or type(val) == float:
#                     continue
                prods_have_atr_val_pair = 0
                for prod in this_prods:
                    if prod in productid_to_attrs and type(productid_to_attrs[prod])!=float:
                        if atr in productid_to_attrs[prod] and type(productid_to_attrs[prod][atr]) != float:
                            if val in productid_to_attrs[prod][atr]:
                                prods_have_atr_val_pair += 1
                if True:#prods_have_atr_val_pair >= 0.1 * len(this_prods):
#                     print '\t', val
                    questions['Q_'+str(counted_atrs)]['A_'+str(counted_vals)] = val
                    counted_vals += 1
                if counted_vals > 5:
                    break
            counted_atrs += 1

        if counted_atrs > 6:
            break  
#     print '\nResults:'
#     questions['results'] = {}
#     for i in [1, 10, 100]:
# #         print prod_to_img[list(this_prods)[i]]
#         questions['results']['img_'+str(i)] = prod_to_img[list(this_prods)[i]]
    if len(questions) > 0:
        categories[gc] = questions
#     print

# %%
for cat, v in categories.items():
    print cat, v, len(v)
# Out:
# 33005440 {'Q_1': {'text': u'lm) PowerLed', 'A_1': u'2 x 2,5 W (2 x 95', 'A_0': u'3 x 2,5 W (3 x 95'}, 'Q_0': {'text': u'IP', 'A_1': u'23', 'A_0': u'20'}} 2
# 42215040 {'Q_0': {'A_5': u'25 cm.', 'A_4': u'35 cm.', 'A_3': u'10 cm.', 'A_2': u'15 - 25 cm.', 'A_1': u'30 - 40 cm.', 'A_0': u'10 - 15 cm.', 'text': u'Korkeus noin'}} 1
# 42205120 {'Q_3': {'A_5': u'4 m', 'A_4': u'1-3 m', 'A_3': u'3 - 4 m', 'A_2': u'1 m', 'A_1': u'2-2,5 m', 'A_0': u'1,5 m', 'text': u'kasvuleveys n.'}, 'Q_2': {'text': u'istutusv\xe4li n.', 'A_1': u'1 m', 'A_0': u'50 cm'}, 'Q_1': {'A_5': u'1-2 m', 'A_4': u'3 m', 'A_3': u'3-10 m', 'A_2': u'10 - 15 m', 'A_1': u'1,5 m', 'A_0': u'25 cm', 'text': u'kasvukorkeus n.'}, 'Q_0': {'text': u'menestymisvy\xf6hykkeet', 'A_1': u'I-IV', 'A_0': u'I-VI'}} 4
# 35502600 {'Q_0': {'text': u'mm laikka', 'A_1': u'125', 'A_0': u'230'}} 1
# ...

# %%
import json
import codecs
with codecs.open('result.json', 'w', "utf-8") as fp:
    fp.write(u''+str(json.dumps(categories)))

# %%
# !pwd
# Out:
# /Users/lokotochek/Desktop/junction/junction_2k16
